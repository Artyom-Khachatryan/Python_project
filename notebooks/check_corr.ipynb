# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the training data files, because test files doesnt have labels
data = pd.read_csv('src/data/flavours_of_physics/training.csv')

# %%
corr = data.corr()

# %%
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# ...

# %%
#production and signal have high corellation(production can be key for predict signal, and we need to remove it)
#we need to delete id, mass column
